# %% [markdown]
# To Do:
# * Next upload: Added Kmeans, operator to imports

# %% [markdown]
# # TOC

# %% [markdown]
# 0. [Imports](#first-bullet)
# 1. [EDA](#1.0-bullet)
# 2. [Data Transformation](#2.0-bullet)
# 3. [Modelling](#3.0-bullet)
# 4. [Output](#4.0-bullet)

# %% [markdown]
# #  <a class="anchor" id="first-bullet">Imports</a>

# %%
#Basic
import pandas as pd
import numpy as np
#Math
import scipy as sp
from random import randint
from math import exp
import operator

#Scraping
'''import requests
import json'''

#Modeling
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.cluster import KMeans
from sklearn.metrics import confusion_matrix

#NLP Processing
'''from sklearn.feature_extraction import stop_words
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer'''

#Time analysis
import time
import datetime
from statsmodels.tsa.stattools import pacf
from statsmodels.graphics.tsaplots import plot_pacf

#Plotting
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# %matplotlib inline

# %% [markdown]
#  # <a class="anchor" id="second-bullet">1. EDA</a>

# %%
data_spray = pd.read_csv('./Data/spray.csv')
data_weather = pd.read_csv('./Data/weather.csv')
data_train = pd.read_csv('./Data/train.csv')
data_test = pd.read_csv('./Data/test.csv')

# %%
#data_weather['weather_day'] = 1
data_spray['spray_day'] = 1
data_spray.columns = ['Date', 'Time', 'Latitude_sp', 'Longitude_sp', 'spray_day']

# %% [markdown]
# ## 1.2 Feature Analysis

# %% [markdown]
# # <a class="anchor" id="2.0-bullet">2. Data Transformation </a>

# %% [markdown]
# ### 2.1 Weather Slice

# %%
weather_station_1 = data_weather.loc[data_weather.Station==1, :]
weather_station_2 = data_weather.loc[data_weather.Station==2, :]

# %%
weather_station_1 = weather_station_1.drop('Station', axis=1)
weather_station_2 = weather_station_2.drop('Station', axis=1)

# %%
weather_station_1.loc[:, ['Date']] = pd.to_datetime(weather_station_1.Date)
weather_station_2.loc[:, ['Date']] = pd.to_datetime(weather_station_2.Date)

# %%
weather_station_1.index = weather_station_1.Date
weather_station_2.index = weather_station_2.Date

# %% [markdown]
# ### 2.2 Convert Weather Objects

# %%
weather_station_1.loc[:, ['Tavg']] = \
weather_station_1['Tavg'].astype('float64')
weather_station_1.loc[:, ['PrecipTotal']] = \
weather_station_1['PrecipTotal'].map(lambda x: .001 if x=='  T' else x).astype(float)
weather_station_1.loc[:, ['SnowFall']] = \
weather_station_1['SnowFall'].map(lambda x: .001 if x=='  T' else x).astype(float)

weather_station_1 = weather_station_1.drop('Depart', axis=1)
weather_station_1 = weather_station_1.drop('Water1', axis=1)

# %%
#Create dummy columns for weather codes

#list all columns
templist = [element for element in weather_station_1['CodeSum'].str.split(' ').tolist()]
newl = []
#get all tags
for element in templist:
    for subelement in element:
        newl.append(subelement)
Codes_list = list(set(newl))
Codes_list.pop(0)

#Create new columns and score 1 if present in original CodeSum value
for code in Codes_list:
    weather_station_1.loc[:, code] = weather_station_1['CodeSum'].str.contains(code)*1
weather_station_1 = weather_station_1.drop('CodeSum', axis=1)

# %%
#find means without 'M' values and fill in blank - less than 5 for each
stnpressure_mean = weather_station_1[weather_station_1['StnPressure']!='M']['StnPressure'].astype(float).mean()
sealevel_mean = weather_station_1[weather_station_1['SeaLevel']!='M']['SeaLevel'].astype(float).mean()
wetbulb_mean = weather_station_1[weather_station_1['WetBulb']!='M']['WetBulb'].astype(float).mean()

# %%
#Replace M with mean, leave others alone
weather_station_1.loc[:, 'StnPressure'] = \
weather_station_1['StnPressure'].map(lambda x: stnpressure_mean if x=='M' else x).astype(float);

weather_station_1.loc[:, 'SeaLevel'] = \
weather_station_1['SeaLevel'].map(lambda x: sealevel_mean if x=='M' else x).astype(float)

weather_station_1.loc[:, 'WetBulb'] = \
weather_station_1['WetBulb'].map(lambda x: wetbulb_mean if x=='M' else x).astype(float);

# %%
#Convert remaining cols to float. Leftover errors from station 1 (Ohare)
obj_cols = [col for col in weather_station_1.columns if weather_station_1[col].dtype=='object']
for col in weather_station_1:
    if col in obj_cols:
        weather_station_1.loc[:, col] = weather_station_1[col].astype('float64')

# %% [markdown]
# ### 2.2 Training Data Munging

# %%
df_train = data_train #Don't edit the initial frame. For recovery

# %% [markdown]
# #### 2.2.1 Time Series

# %% [markdown]
# #### 2.2.1.1 Establishing Basic Features

# %%
#Convert to Date Time from object
df_train.loc[:, ['Date']]= pd.to_datetime(df_train['Date'])

#Switch to DateTime Index
df_train.index = df_train.Date

#Create Days from start column for easy analysis
BeginDate = datetime.date(2007, 4, 30)
df_train.loc[:, 'DaysFrom'] = df_train.index - pd.to_datetime(BeginDate)
#extract date number from datetime entry. Should capture broad time dependence
df_train.loc[:, 'DaysFrom'] = df_train['DaysFrom'].astype(str).str.replace(' days 00:00:00.000000000', '').astype(int)
#Extract Month information
df_train.loc[:, 'Month'] = df_train.index.month

# %%
plt.figure(figsize=(10,5))
plt.plot(df_train['WnvPresent'].resample('D').sum().rolling(window=14).mean(), alpha=1, lw=2)

# %%
fig, ax = plt.subplots(figsize=(12,5))
plot_pacf(df_train.NumMosquitos, lags=30, ax=ax)
plt.show()

# %%
#sig bumps at 1,2. bumps at 14, 30
wnv_rolling_1 = df_train['WnvPresent'].resample('D').sum().rolling(window=1).mean()
wnv_rolling_2 = df_train['WnvPresent'].resample('D').sum().rolling(window=2).mean()
wnv_rolling_14 = df_train['WnvPresent'].resample('D').sum().rolling(window=14).mean()
wnv_rolling_30 = df_train['WnvPresent'].resample('D').sum().rolling(window=30).mean()

# %%
numM_rolling_1 = df_train['WnvPresent'].resample('D').sum().rolling(window=1).mean()
numM_rolling_2 = df_train['WnvPresent'].resample('D').sum().rolling(window=2).mean()
numM_rolling_6 = df_train['WnvPresent'].resample('D').sum().rolling(window=6).mean()
numM_rolling_13 = df_train['WnvPresent'].resample('D').sum().rolling(window=13).mean()

# %% [markdown]
# #### 2.2.1.2 Seasonal Adjustments to Baseline Probability

# %%
#Create a normalized graph to observe seasonality across years
year_day = pd.DataFrame(df_train.index.dayofyear)
year_day['Wnv'] = pd.DataFrame(df_train['WnvPresent']).reset_index().drop('Date', axis=1)
#Total number of occurences by day of the year
daily_sums = year_day.groupby(by='Date').sum()

# %%
#Shift up two days to capture Friday-Monday jump
#2 seems to be an appropriate normalization factor
normizer = 2
rolls = pd.Series([daily_sums.iloc[row-5:row+2].mean().sum()*normizer for row in range(len(daily_sums))])
rolls.index = daily_sums.index
plt.plot(rolls)
plt.plot(year_day.groupby(by='Date').sum());#confirm this is from skipped weekends or something

# %%
#Normalize by total rows used in calculation
rolling_count = year_day.groupby(by='Date').count()
rolling_average_rate = rolls / rolling_count['Wnv'].mean()/normizer
plt.plot( rolling_average_rate)
plt.plot(year_day.groupby(by='Date').sum() /rolling_count)

# %% [markdown]
# #### 2.2.2 Dummy Columns

# %%
df_species_dummies = pd.get_dummies(df_train['Species'])

df_block_dummies = pd.get_dummies(df_train['Block'])

df_trap_dummies = pd.get_dummies(df_train['Trap'])

# %%
df_weekday_dummies = pd.get_dummies(df_train.index.weekday_name)
df_weekday_dummies.index=df_train.index

# %% [markdown]
# #### 2.2.3 Remove Un-Needed and Recombine

# %%
cols_to_drop = ['Address', 'Species', 'Block', 'Street', 'Trap', 'AddressNumberAndStreet', 'AddressAccuracy', 'Date']

# %%
df_train = df_train.drop(cols_to_drop, axis=1)

# %% [markdown]
# Series to add
#   West Nile Rolling prevalence
# wnv_rolling_1
# wnv_rolling_2
# wnv_rolling_14
# wnv_rolling_30
#   Rolling Mosquito counts
# numM_rolling_1
# numM_rolling_2
# numM_rolling_6
# numM_rolling_13
#
# DataFrame Dummies to add
# df_species_dummies
# df_block_dummies
# df_trap_dummies

# %%
#CAUTION: JOINING DATAFRAMES IS MEMORY INTENSIVE

# %%
#YOU HAVE BEEN WARNED

# %%
df_train = pd.concat([df_train,df_species_dummies, df_weekday_dummies], axis=1)

# %%
#Add measurement back in 
df_train['YearDay'] = df_train.index.dayofyear

rolling_average_rate = pd.DataFrame(rolling_average_rate, columns=['seasonal_baseline'])

#df_train = df_train.join(rolling_average_rate, on='YearDay', how='left')

# %%
df_train.columns
# Out:
# Index(['Latitude', 'Longitude', 'NumMosquitos', 'WnvPresent', 'DaysFrom',
#        'Month', 'CULEX ERRATICUS', 'CULEX PIPIENS', 'CULEX PIPIENS/RESTUANS',
#        'CULEX RESTUANS', 'CULEX SALINARIUS', 'CULEX TARSALIS',
#        'CULEX TERRITANS', 'Friday', 'Monday', 'Thursday', 'Tuesday',
#        'Wednesday', 'YearDay'],
#       dtype='object')

# %% [markdown]
# ## 2.9 Combine Data and Assess

# %%
df_rolling = weather_station_1.resample('D').sum().rolling(window=7).mean().shift()

# %%
df_train = df_train.join(df_rolling, how='left')

# %%
df_train.head()
# Out:
#              Latitude  Longitude  NumMosquitos  WnvPresent  DaysFrom  Month  \
# Date
# 2007-05-29  41.954690 -87.800991             1           0        29      5
# 2007-05-29  41.954690 -87.800991             1           0        29      5
# 2007-05-29  41.994991 -87.769279             1           0        29      5
# 2007-05-29  41.974089 -87.824812             1           0        29      5
# 2007-05-29  41.974089 -87.824812             4           0        29      5
#
#             CULEX ERRATICUS  CULEX PIPIENS  CULEX PIPIENS/RESTUANS  \
# Date
# 2007-05-29                0              0                       1
# 2007-05-29                0              0                       0
# 2007-05-29                0              0                       0
# 2007-05-29                0              0                       1
# 2007-05-29                0              0                       0
#
#             CULEX RESTUANS ...    FU        TS  BCFG   SQ        BR  FG+  \
# Date                       ...
# 2007-05-29               0 ...   0.0  0.142857   0.0  0.0  0.285714  0.0
# 2007-05-29               1 ...   0.0  0.142857   0.0  0.0  0.285714  0.0
# 2007-05-29               1 ...   0.0  0.142857   0.0  0.0  0.285714  0.0
# 2007-05-29               0 ...   0.0  0.142857   0.0  0.0  0.285714  0.0
# 2007-05-29               1 ...   0.0  0.142857   0.0  0.0  0.285714  0.0
#
#             VCTS   FG  MIFG   SN
# Date
# 2007-05-29   0.0  0.0   0.0  0.0
# 2007-05-29   0.0  0.0   0.0  0.0
# 2007-05-29   0.0  0.0   0.0  0.0
# 2007-05-29   0.0  0.0   0.0  0.0
# 2007-05-29   0.0  0.0   0.0  0.0
#
# [5 rows x 50 columns]

# %% [markdown]
# # <a class="anchor" id="3.0-bullet">3. Model </a>

# %% [markdown]
# ## 3.1 Build Model

# %%
cols_to_exclude = ['WnvPresent', 'NumMosquitos', 'DaysFrom', 
                   'Sunrise', 'Sunset', 'YearDay', 'Month', 'seasonal_baseline']
model_cols = [col for col in df_train.columns if col not in cols_to_exclude]

# %%
X = df_train.loc[:, model_cols]
y = df_train['WnvPresent']

# %%
#Stratification on Days From should ensure usable spread in time data. Should get most periods in train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=X.index, random_state=42)

# %% [markdown]
# ### 3.1.2 GridSearch KKN

# %%
paramz = {
    'n_neighbors': [3, 5, 7, 8, 20]
}
gs=GridSearchCV(KNeighborsClassifier(), param_grid=paramz)
gs.fit(X_train, y_train)
print('   Score: ', gs.score(X_test, y_test))
# Out:
#    Score:  0.9444232965359726

# %%
gs.best_params_
# Out:
# {'n_neighbors': 8}

# %%
#Option 2: Use Something Else
knc = KNeighborsClassifier(8)
knc.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=8, p=2,
#            weights='uniform')

# %%
kpreds = knc.predict_proba(X_test)

# %%
wnv_preds = [proba[1] for proba in kpreds]

# %%
wnv_preds_adj = [1*(pred > .1) for pred in wnv_preds]
sns.distplot(wnv_preds)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
cm = confusion_matrix(y_test, wnv_preds_adj)
df_cm = pd.DataFrame(cm, columns=['Predicted 0', 'Pred 1'], index=['Actual 0', 'Actual 1'])
df_cm
# Out:
#           Predicted 0  Pred 1
# Actual 0         1901     581
# Actual 1           51      94

# %%
X_test_mod = X_test

# %%
[col for col in X_test.columns if col not in X_train.columns]
# Out:
# []

# %%
X_test_mod['YearDay'] =X_test_mod.index.dayofyear
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
X_test_mod= X_test_mod.join(rolling_average_rate, on='YearDay', how='left')

# %%
wnv_preds2 = [X_test_mod['seasonal_baseline'][i] + wnv_preds[i] for i in range(len(X_test_mod))]

# %%
wnv_preds_adj2 = [1*(pred > .1) for pred in wnv_preds2]

# %%
cm = confusion_matrix(y_test, wnv_preds_adj2)
df_cm = pd.DataFrame(cm, columns=['Predicted 0', 'Pred 1'], index=['Actual 0', 'Actual 1'])
df_cm
# Out:
#           Predicted 0  Pred 1
# Actual 0         1623     859
# Actual 1           24     121

# %%
from sklearn.metrics import roc_auc_score

# %%
roc_auc_score(y_test, wnv_preds)
# Out:
# 0.731430437077996

# %%
for i in range(1, 90, 5):
    print('    i:{} score:{}'.format(i, roc_auc_score(y_test, [1*(pred > i/100) for pred in wnv_preds2])))
# Out:
#     i:1 score:0.650459862735836
#     i:6 score:0.6941634944010671
#     i:11 score:0.7385909583483843
#     i:16 score:0.7265053210703271
#     i:21 score:0.728153046764289
#     i:26 score:0.6811220095029036
#     i:31 score:0.6570910556003223
#     i:36 score:0.6139820500708549
#     i:41 score:0.6035899858290034
#     i:46 score:0.5802342382394621
#     i:51 score:0.5489510683820057
#     i:56 score:0.5475172969518464
#     i:61 score:0.5237586484759232
#     i:66 score:0.5237586484759232
#     i:71 score:0.5211161743866182
#     i:76 score:0.51623412709439
#     i:81 score:0.5166370279807719
#     i:86 score:0.5101433771430159

# %%
for i in range(1, 90, 5):
    print('    i:{} score:{}'.format(i, roc_auc_score(y_test, [1*(pred > i/100) for pred in wnv_preds])))
# Out:
#     i:1 score:0.7070952235405262
#     i:6 score:0.7070952235405262
#     i:11 score:0.7070952235405262
#     i:16 score:0.6619258662369057
#     i:21 score:0.6619258662369057
#     i:26 score:0.5771652449359527
#     i:31 score:0.5771652449359527
#     i:36 score:0.5771652449359527
#     i:41 score:0.5399927755703131
#     i:46 score:0.5399927755703131
#     i:51 score:0.522526327488955
#     i:56 score:0.522526327488955
#     i:61 score:0.522526327488955
#     i:66 score:0.5133902025618939
#     i:71 score:0.5133902025618939
#     i:76 score:0.503448275862069
#     i:81 score:0.503448275862069
#     i:86 score:0.503448275862069

# %% [markdown]
# ## 3.2 Assess Model

# %% [markdown]
# # <a class="anchor" id="4.0-bullet">4. Output</a>

# %% [markdown]
# ## 4.1 Transform test data

# %%
df_test = data_test

# %%
df_test.shape
# Out:
# (116293, 13)

# %% [markdown]
# ### 4.1.3 Time Series

# %%
#Transform index to time

# %%
#Convert to Date Time from object
df_test.loc[:, ['Date']]= pd.to_datetime(df_test['Date'])

#Switch to DateTime Index
df_test.index = df_test.Date

#Create Days from start column for easy analysis

df_test.loc[:, 'DaysFrom'] = df_test.index - pd.to_datetime(BeginDate)
#extract date number from datetime entry. Should capture broad time dependence
df_test.loc[:, 'DaysFrom'] = df_test['DaysFrom'].astype(str).str.replace(' days 00:00:00.000000000', '').astype(int)
#Extract Month information
df_test.loc[:, 'Month'] = df_test.index.month

# %%
#Get weekday dummies
df_test_weekday = pd.get_dummies(df_test.index.weekday_name)
df_test_weekday.index = df_test.index

# %%
df_test = pd.concat([df_test, df_test_weekday], axis=1)

# %%
#Create seasonal baseline for add back

# %%
df_test['YearDay'] = df_test.index.dayofyear

# %%
temp = df_test.join(rolling_average_rate, on='YearDay', how='left')

# %%
#come back to this - need to fill in blank for seasonal_baseline

# %%
rolling_average_rate.index
# Out:
# Int64Index([148, 149, 153, 154, 156, 158, 161, 163, 165, 166, 168, 170, 172,
#             173, 175, 177, 178, 179, 180, 181, 183, 187, 189, 191, 192, 193,
#             194, 196, 198, 199, 200, 205, 206, 208, 210, 212, 213, 214, 215,
#             217, 219, 220, 221, 224, 225, 227, 228, 229, 231, 233, 234, 236,
#             237, 238, 239, 240, 241, 244, 245, 246, 247, 248, 249, 255, 257,
#             259, 260, 261, 262, 266, 267, 268, 269, 273, 274, 277, 282],
#            dtype='int64', name='Date')

# %% [markdown]
# ### 4.1.3 Categorical

# %%
df_test_species = pd.get_dummies(df_test['Species'])

# %%
[col for col in df_test_species.columns if col not in df_species_dummies.columns]
# Out:
# ['UNSPECIFIED CULEX']

# %%
df_test_species = df_test_species.drop('UNSPECIFIED CULEX', axis=1)

# %%
df_test = pd.concat([df_test,df_test_species], axis=1)

# %%
df_test
# Out:
#                 Id       Date  \
# Date
# 2008-06-11       1 2008-06-11
# 2008-06-11       2 2008-06-11
# 2008-06-11       3 2008-06-11
# 2008-06-11       4 2008-06-11
# 2008-06-11       5 2008-06-11
# 2008-06-11       6 2008-06-11
# 2008-06-11       7 2008-06-11
# 2008-06-11       8 2008-06-11
# 2008-06-11       9 2008-06-11
# 2008-06-11      10 2008-06-11
# 2008-06-11      11 2008-06-11
# 2008-06-11      12 2008-06-11
# 2008-06-11      13 2008-06-11
# 2008-06-11      14 2008-06-11
# 2008-06-11      15 2008-06-11
# 2008-06-11      16 2008-06-11
# 2008-06-11      17 2008-06-11
# 2008-06-11      18 2008-06-11
# 2008-06-11      19 2008-06-11
# 2008-06-11      20 2008-06-11
# 2008-06-11      21 2008-06-11
# 2008-06-11      22 2008-06-11
# 2008-06-11      23 2008-06-11
# 2008-06-11      24 2008-06-11
# 2008-06-11      25 2008-06-11
# 2008-06-11      26 2008-06-11
# 2008-06-11      27 2008-06-11
# 2008-06-11      28 2008-06-11
# 2008-06-11      29 2008-06-11
# 2008-06-11      30 2008-06-11
# ...            ...        ...
# 2014-10-02  116264 2014-10-02
# 2014-10-02  116265 2014-10-02
# 2014-10-02  116266 2014-10-02
# 2014-10-02  116267 2014-10-02
# 2014-10-02  116268 2014-10-02
# 2014-10-02  116269 2014-10-02
# 2014-10-02  116270 2014-10-02
# 2014-10-02  116271 2014-10-02
# 2014-10-02  116272 2014-10-02
# 2014-10-02  116273 2014-10-02
# 2014-10-02  116274 2014-10-02
# 2014-10-02  116275 2014-10-02
# 2014-10-02  116276 2014-10-02
# 2014-10-02  116277 2014-10-02
# 2014-10-02  116278 2014-10-02
# 2014-10-02  116279 2014-10-02
# 2014-10-02  116280 2014-10-02
# 2014-10-02  116281 2014-10-02
# 2014-10-02  116282 2014-10-02
# 2014-10-02  116283 2014-10-02
# 2014-10-02  116284 2014-10-02
# 2014-10-02  116285 2014-10-02
# 2014-10-02  116286 2014-10-02
# 2014-10-02  116287 2014-10-02
# 2014-10-02  116288 2014-10-02
# 2014-10-02  116289 2014-10-02
# 2014-10-02  116290 2014-10-02
# 2014-10-02  116291 2014-10-02
# 2014-10-02  116292 2014-10-02
# 2014-10-02  116293 2014-10-02
#
#                                                       Address  \
# Date
# 2008-06-11  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2008-06-11  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2008-06-11  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2008-06-11  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2008-06-11  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2008-06-11  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2008-06-11  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2008-06-11  4100 North Oak Park Avenue, Chicago, IL 60634,...
# 2008-06-11  6200 North Mandell Avenue, Chicago, IL 60646, USA
# 2008-06-11  6200 North Mandell Avenue, Chicago, IL 60646, USA
# 2008-06-11  6200 North Mandell Avenue, Chicago, IL 60646, USA
# 2008-06-11  6200 North Mandell Avenue, Chicago, IL 60646, USA
# 2008-06-11  6200 North Mandell Avenue, Chicago, IL 60646, USA
# 2008-06-11  6200 North Mandell Avenue, Chicago, IL 60646, USA
# 2008-06-11  6200 North Mandell Avenue, Chicago, IL 60646, USA
# 2008-06-11  6200 North Mandell Avenue, Chicago, IL 60646, USA
# 2008-06-11    7900 West Foster Avenue, Chicago, IL 60656, USA
# 2008-06-11    7900 West Foster Avenue, Chicago, IL 60656, USA
# 2008-06-11    7900 West Foster Avenue, Chicago, IL 60656, USA
# 2008-06-11    7900 West Foster Avenue, Chicago, IL 60656, USA
# 2008-06-11    7900 West Foster Avenue, Chicago, IL 60656, USA
# 2008-06-11    7900 West Foster Avenue, Chicago, IL 60656, USA
# 2008-06-11    7900 West Foster Avenue, Chicago, IL 60656, USA
# 2008-06-11    7900 West Foster Avenue, Chicago, IL 60656, USA
# 2008-06-11   1500 West Webster Avenue, Chicago, IL 60614, USA
# 2008-06-11   1500 West Webster Avenue, Chicago, IL 60614, USA
# 2008-06-11   1500 West Webster Avenue, Chicago, IL 60614, USA
# 2008-06-11   1500 West Webster Avenue, Chicago, IL 60614, USA
# 2008-06-11   1500 West Webster Avenue, Chicago, IL 60614, USA
# 2008-06-11   1500 West Webster Avenue, Chicago, IL 60614, USA
# ...                                                       ...
# 2014-10-02      3400 West 77th Street, Chicago, IL 60652, USA
# 2014-10-02      3400 West 77th Street, Chicago, IL 60652, USA
# 2014-10-02      3400 West 77th Street, Chicago, IL 60652, USA
# 2014-10-02      3400 West 77th Street, Chicago, IL 60652, USA
# 2014-10-02      3400 West 77th Street, Chicago, IL 60652, USA
# 2014-10-02      3400 West 77th Street, Chicago, IL 60652, USA
# 2014-10-02       5100 West 63rd Place, Chicago, IL 60638, USA
# 2014-10-02       5100 West 63rd Place, Chicago, IL 60638, USA
# 2014-10-02       5100 West 63rd Place, Chicago, IL 60638, USA
# 2014-10-02       5100 West 63rd Place, Chicago, IL 60638, USA
# 2014-10-02       5100 West 63rd Place, Chicago, IL 60638, USA
# 2014-10-02       5100 West 63rd Place, Chicago, IL 60638, USA
# 2014-10-02       5100 West 63rd Place, Chicago, IL 60638, USA
# 2014-10-02       5100 West 63rd Place, Chicago, IL 60638, USA
# 2014-10-02  9600 South Longwood Drive, Chicago, IL 60643, USA
# 2014-10-02  9600 South Longwood Drive, Chicago, IL 60643, USA
# 2014-10-02  9600 South Longwood Drive, Chicago, IL 60643, USA
# 2014-10-02  9600 South Longwood Drive, Chicago, IL 60643, USA
# 2014-10-02  9600 South Longwood Drive, Chicago, IL 60643, USA
# 2014-10-02  9600 South Longwood Drive, Chicago, IL 60643, USA
# 2014-10-02  9600 South Longwood Drive, Chicago, IL 60643, USA
# 2014-10-02  9600 South Longwood Drive, Chicago, IL 60643, USA
# 2014-10-02    2100 North Cannon Drive, Chicago, IL 60614, USA
# 2014-10-02    2100 North Cannon Drive, Chicago, IL 60614, USA
# 2014-10-02    2100 North Cannon Drive, Chicago, IL 60614, USA
# 2014-10-02    2100 North Cannon Drive, Chicago, IL 60614, USA
# 2014-10-02    2100 North Cannon Drive, Chicago, IL 60614, USA
# 2014-10-02    2100 North Cannon Drive, Chicago, IL 60614, USA
# 2014-10-02    2100 North Cannon Drive, Chicago, IL 60614, USA
# 2014-10-02    2100 North Cannon Drive, Chicago, IL 60614, USA
#
#                            Species  Block           Street   Trap  \
# Date
# 2008-06-11  CULEX PIPIENS/RESTUANS     41   N OAK PARK AVE   T002
# 2008-06-11          CULEX RESTUANS     41   N OAK PARK AVE   T002
# 2008-06-11           CULEX PIPIENS     41   N OAK PARK AVE   T002
# 2008-06-11        CULEX SALINARIUS     41   N OAK PARK AVE   T002
# 2008-06-11         CULEX TERRITANS     41   N OAK PARK AVE   T002
# 2008-06-11          CULEX TARSALIS     41   N OAK PARK AVE   T002
# 2008-06-11       UNSPECIFIED CULEX     41   N OAK PARK AVE   T002
# 2008-06-11         CULEX ERRATICUS     41   N OAK PARK AVE   T002
# 2008-06-11  CULEX PIPIENS/RESTUANS     62    N MANDELL AVE   T007
# 2008-06-11          CULEX RESTUANS     62    N MANDELL AVE   T007
# 2008-06-11           CULEX PIPIENS     62    N MANDELL AVE   T007
# 2008-06-11        CULEX SALINARIUS     62    N MANDELL AVE   T007
# 2008-06-11         CULEX TERRITANS     62    N MANDELL AVE   T007
# 2008-06-11          CULEX TARSALIS     62    N MANDELL AVE   T007
# 2008-06-11       UNSPECIFIED CULEX     62    N MANDELL AVE   T007
# 2008-06-11         CULEX ERRATICUS     62    N MANDELL AVE   T007
# 2008-06-11  CULEX PIPIENS/RESTUANS     79     W FOSTER AVE   T015
# 2008-06-11          CULEX RESTUANS     79     W FOSTER AVE   T015
# 2008-06-11           CULEX PIPIENS     79     W FOSTER AVE   T015
# 2008-06-11        CULEX SALINARIUS     79     W FOSTER AVE   T015
# 2008-06-11         CULEX TERRITANS     79     W FOSTER AVE   T015
# 2008-06-11          CULEX TARSALIS     79     W FOSTER AVE   T015
# 2008-06-11       UNSPECIFIED CULEX     79     W FOSTER AVE   T015
# 2008-06-11         CULEX ERRATICUS     79     W FOSTER AVE   T015
# 2008-06-11  CULEX PIPIENS/RESTUANS     15    W WEBSTER AVE   T045
# 2008-06-11          CULEX RESTUANS     15    W WEBSTER AVE   T045
# 2008-06-11           CULEX PIPIENS     15    W WEBSTER AVE   T045
# 2008-06-11        CULEX SALINARIUS     15    W WEBSTER AVE   T045
# 2008-06-11         CULEX TERRITANS     15    W WEBSTER AVE   T045
# 2008-06-11          CULEX TARSALIS     15    W WEBSTER AVE   T045
# ...                            ...    ...              ...    ...
# 2014-10-02           CULEX PIPIENS     34        W 77TH ST   T238
# 2014-10-02        CULEX SALINARIUS     34        W 77TH ST   T238
# 2014-10-02         CULEX TERRITANS     34        W 77TH ST   T238
# 2014-10-02          CULEX TARSALIS     34        W 77TH ST   T238
# 2014-10-02       UNSPECIFIED CULEX     34        W 77TH ST   T238
# 2014-10-02         CULEX ERRATICUS     34        W 77TH ST   T238
# 2014-10-02  CULEX PIPIENS/RESTUANS     51        W 63RD PL  T065A
# 2014-10-02          CULEX RESTUANS     51        W 63RD PL  T065A
# 2014-10-02           CULEX PIPIENS     51        W 63RD PL  T065A
# 2014-10-02        CULEX SALINARIUS     51        W 63RD PL  T065A
# 2014-10-02         CULEX TERRITANS     51        W 63RD PL  T065A
# 2014-10-02          CULEX TARSALIS     51        W 63RD PL  T065A
# 2014-10-02       UNSPECIFIED CULEX     51        W 63RD PL  T065A
# 2014-10-02         CULEX ERRATICUS     51        W 63RD PL  T065A
# 2014-10-02  CULEX PIPIENS/RESTUANS     96    S LONGWOOD DR  T094B
# 2014-10-02          CULEX RESTUANS     96    S LONGWOOD DR  T094B
# 2014-10-02           CULEX PIPIENS     96    S LONGWOOD DR  T094B
# 2014-10-02        CULEX SALINARIUS     96    S LONGWOOD DR  T094B
# 2014-10-02         CULEX TERRITANS     96    S LONGWOOD DR  T094B
# 2014-10-02          CULEX TARSALIS     96    S LONGWOOD DR  T094B
# 2014-10-02       UNSPECIFIED CULEX     96    S LONGWOOD DR  T094B
# 2014-10-02         CULEX ERRATICUS     96    S LONGWOOD DR  T094B
# 2014-10-02  CULEX PIPIENS/RESTUANS     21      N CANNON DR  T054C
# 2014-10-02          CULEX RESTUANS     21      N CANNON DR  T054C
# 2014-10-02           CULEX PIPIENS     21      N CANNON DR  T054C
# 2014-10-02        CULEX SALINARIUS     21      N CANNON DR  T054C
# 2014-10-02         CULEX TERRITANS     21      N CANNON DR  T054C
# 2014-10-02          CULEX TARSALIS     21      N CANNON DR  T054C
# 2014-10-02       UNSPECIFIED CULEX     21      N CANNON DR  T054C
# 2014-10-02         CULEX ERRATICUS     21      N CANNON DR  T054C
#
#                        AddressNumberAndStreet   Latitude  Longitude  \
# Date
# 2008-06-11  4100  N OAK PARK AVE, Chicago, IL  41.954690 -87.800991
# 2008-06-11  4100  N OAK PARK AVE, Chicago, IL  41.954690 -87.800991
# 2008-06-11  4100  N OAK PARK AVE, Chicago, IL  41.954690 -87.800991
# 2008-06-11  4100  N OAK PARK AVE, Chicago, IL  41.954690 -87.800991
# 2008-06-11  4100  N OAK PARK AVE, Chicago, IL  41.954690 -87.800991
# 2008-06-11  4100  N OAK PARK AVE, Chicago, IL  41.954690 -87.800991
# 2008-06-11  4100  N OAK PARK AVE, Chicago, IL  41.954690 -87.800991
# 2008-06-11  4100  N OAK PARK AVE, Chicago, IL  41.954690 -87.800991
# 2008-06-11   6200  N MANDELL AVE, Chicago, IL  41.994991 -87.769279
# 2008-06-11   6200  N MANDELL AVE, Chicago, IL  41.994991 -87.769279
# 2008-06-11   6200  N MANDELL AVE, Chicago, IL  41.994991 -87.769279
# 2008-06-11   6200  N MANDELL AVE, Chicago, IL  41.994991 -87.769279
# 2008-06-11   6200  N MANDELL AVE, Chicago, IL  41.994991 -87.769279
# 2008-06-11   6200  N MANDELL AVE, Chicago, IL  41.994991 -87.769279
# 2008-06-11   6200  N MANDELL AVE, Chicago, IL  41.994991 -87.769279
# 2008-06-11   6200  N MANDELL AVE, Chicago, IL  41.994991 -87.769279
# 2008-06-11    7900  W FOSTER AVE, Chicago, IL  41.974089 -87.824812
# 2008-06-11    7900  W FOSTER AVE, Chicago, IL  41.974089 -87.824812
# 2008-06-11    7900  W FOSTER AVE, Chicago, IL  41.974089 -87.824812
# 2008-06-11    7900  W FOSTER AVE, Chicago, IL  41.974089 -87.824812
# 2008-06-11    7900  W FOSTER AVE, Chicago, IL  41.974089 -87.824812
# 2008-06-11    7900  W FOSTER AVE, Chicago, IL  41.974089 -87.824812
# 2008-06-11    7900  W FOSTER AVE, Chicago, IL  41.974089 -87.824812
# 2008-06-11    7900  W FOSTER AVE, Chicago, IL  41.974089 -87.824812
# 2008-06-11   1500  W WEBSTER AVE, Chicago, IL  41.921600 -87.666455
# 2008-06-11   1500  W WEBSTER AVE, Chicago, IL  41.921600 -87.666455
# 2008-06-11   1500  W WEBSTER AVE, Chicago, IL  41.921600 -87.666455
# 2008-06-11   1500  W WEBSTER AVE, Chicago, IL  41.921600 -87.666455
# 2008-06-11   1500  W WEBSTER AVE, Chicago, IL  41.921600 -87.666455
# 2008-06-11   1500  W WEBSTER AVE, Chicago, IL  41.921600 -87.666455
# ...                                       ...        ...        ...
# 2014-10-02       3400  W 77TH ST, Chicago, IL  41.753391 -87.707394
# 2014-10-02       3400  W 77TH ST, Chicago, IL  41.753391 -87.707394
# 2014-10-02       3400  W 77TH ST, Chicago, IL  41.753391 -87.707394
# 2014-10-02       3400  W 77TH ST, Chicago, IL  41.753391 -87.707394
# 2014-10-02       3400  W 77TH ST, Chicago, IL  41.753391 -87.707394
# 2014-10-02       3400  W 77TH ST, Chicago, IL  41.753391 -87.707394
# 2014-10-02       5100  W 63RD PL, Chicago, IL  41.777689 -87.749149
# 2014-10-02       5100  W 63RD PL, Chicago, IL  41.777689 -87.749149
# 2014-10-02       5100  W 63RD PL, Chicago, IL  41.777689 -87.749149
# 2014-10-02       5100  W 63RD PL, Chicago, IL  41.777689 -87.749149
# 2014-10-02       5100  W 63RD PL, Chicago, IL  41.777689 -87.749149
# 2014-10-02       5100  W 63RD PL, Chicago, IL  41.777689 -87.749149
# 2014-10-02       5100  W 63RD PL, Chicago, IL  41.777689 -87.749149
# 2014-10-02       5100  W 63RD PL, Chicago, IL  41.777689 -87.749149
# 2014-10-02   9600  S LONGWOOD DR, Chicago, IL  41.719140 -87.669539
# 2014-10-02   9600  S LONGWOOD DR, Chicago, IL  41.719140 -87.669539
# 2014-10-02   9600  S LONGWOOD DR, Chicago, IL  41.719140 -87.669539
# 2014-10-02   9600  S LONGWOOD DR, Chicago, IL  41.719140 -87.669539
# 2014-10-02   9600  S LONGWOOD DR, Chicago, IL  41.719140 -87.669539
# 2014-10-02   9600  S LONGWOOD DR, Chicago, IL  41.719140 -87.669539
# 2014-10-02   9600  S LONGWOOD DR, Chicago, IL  41.719140 -87.669539
# 2014-10-02   9600  S LONGWOOD DR, Chicago, IL  41.719140 -87.669539
# 2014-10-02     2100  N CANNON DR, Chicago, IL  41.925652 -87.633590
# 2014-10-02     2100  N CANNON DR, Chicago, IL  41.925652 -87.633590
# 2014-10-02     2100  N CANNON DR, Chicago, IL  41.925652 -87.633590
# 2014-10-02     2100  N CANNON DR, Chicago, IL  41.925652 -87.633590
# 2014-10-02     2100  N CANNON DR, Chicago, IL  41.925652 -87.633590
# 2014-10-02     2100  N CANNON DR, Chicago, IL  41.925652 -87.633590
# 2014-10-02     2100  N CANNON DR, Chicago, IL  41.925652 -87.633590
# 2014-10-02     2100  N CANNON DR, Chicago, IL  41.925652 -87.633590
#
#                  ...         Tuesday  Wednesday  YearDay  CULEX ERRATICUS  \
# Date             ...
# 2008-06-11       ...               0          1      163                0
# 2008-06-11       ...               0          1      163                0
# 2008-06-11       ...               0          1      163                0
# 2008-06-11       ...               0          1      163                0
# 2008-06-11       ...               0          1      163                0
# 2008-06-11       ...               0          1      163                0
# 2008-06-11       ...               0          1      163                0
# 2008-06-11       ...               0          1      163                1
# 2008-06-11       ...               0          1      163                0
# 2008-06-11       ...               0          1      163                0
# 2008-06-11       ...               0          1      163                0
# 2008-06-11       ...               0          1      163                0
# 2008-06-11       ...               0          1      163                0
# 2008-06-11       ...               0          1      163                0
# 2008-06-11       ...               0          1      163                0
# 2008-06-11       ...               0          1      163                1
# 2008-06-11       ...               0          1      163                0
# 2008-06-11       ...               0          1      163                0
# 2008-06-11       ...               0          1      163                0
# 2008-06-11       ...               0          1      163                0
# 2008-06-11       ...               0          1      163                0
# 2008-06-11       ...               0          1      163                0
# 2008-06-11       ...               0          1      163                0
# 2008-06-11       ...               0          1      163                1
# 2008-06-11       ...               0          1      163                0
# 2008-06-11       ...               0          1      163                0
# 2008-06-11       ...               0          1      163                0
# 2008-06-11       ...               0          1      163                0
# 2008-06-11       ...               0          1      163                0
# 2008-06-11       ...               0          1      163                0
# ...              ...             ...        ...      ...              ...
# 2014-10-02       ...               0          0      275                0
# 2014-10-02       ...               0          0      275                0
# 2014-10-02       ...               0          0      275                0
# 2014-10-02       ...               0          0      275                0
# 2014-10-02       ...               0          0      275                0
# 2014-10-02       ...               0          0      275                1
# 2014-10-02       ...               0          0      275                0
# 2014-10-02       ...               0          0      275                0
# 2014-10-02       ...               0          0      275                0
# 2014-10-02       ...               0          0      275                0
# 2014-10-02       ...               0          0      275                0
# 2014-10-02       ...               0          0      275                0
# 2014-10-02       ...               0          0      275                0
# 2014-10-02       ...               0          0      275                1
# 2014-10-02       ...               0          0      275                0
# 2014-10-02       ...               0          0      275                0
# 2014-10-02       ...               0          0      275                0
# 2014-10-02       ...               0          0      275                0
# 2014-10-02       ...               0          0      275                0
# 2014-10-02       ...               0          0      275                0
# 2014-10-02       ...               0          0      275                0
# 2014-10-02       ...               0          0      275                1
# 2014-10-02       ...               0          0      275                0
# 2014-10-02       ...               0          0      275                0
# 2014-10-02       ...               0          0      275                0
# 2014-10-02       ...               0          0      275                0
# 2014-10-02       ...               0          0      275                0
# 2014-10-02       ...               0          0      275                0
# 2014-10-02       ...               0          0      275                0
# 2014-10-02       ...               0          0      275                1
#
#             CULEX PIPIENS  CULEX PIPIENS/RESTUANS  CULEX RESTUANS  \
# Date
# 2008-06-11              0                       1               0
# 2008-06-11              0                       0               1
# 2008-06-11              1                       0               0
# 2008-06-11              0                       0               0
# 2008-06-11              0                       0               0
# 2008-06-11              0                       0               0
# 2008-06-11              0                       0               0
# 2008-06-11              0                       0               0
# 2008-06-11              0                       1               0
# 2008-06-11              0                       0               1
# 2008-06-11              1                       0               0
# 2008-06-11              0                       0               0
# 2008-06-11              0                       0               0
# 2008-06-11              0                       0               0
# 2008-06-11              0                       0               0
# 2008-06-11              0                       0               0
# 2008-06-11              0                       1               0
# 2008-06-11              0                       0               1
# 2008-06-11              1                       0               0
# 2008-06-11              0                       0               0
# 2008-06-11              0                       0               0
# 2008-06-11              0                       0               0
# 2008-06-11              0                       0               0
# 2008-06-11              0                       0               0
# 2008-06-11              0                       1               0
# 2008-06-11              0                       0               1
# 2008-06-11              1                       0               0
# 2008-06-11              0                       0               0
# 2008-06-11              0                       0               0
# 2008-06-11              0                       0               0
# ...                   ...                     ...             ...
# 2014-10-02              1                       0               0
# 2014-10-02              0                       0               0
# 2014-10-02              0                       0               0
# 2014-10-02              0                       0               0
# 2014-10-02              0                       0               0
# 2014-10-02              0                       0               0
# 2014-10-02              0                       1               0
# 2014-10-02              0                       0               1
# 2014-10-02              1                       0               0
# 2014-10-02              0                       0               0
# 2014-10-02              0                       0               0
# 2014-10-02              0                       0               0
# 2014-10-02              0                       0               0
# 2014-10-02              0                       0               0
# 2014-10-02              0                       1               0
# 2014-10-02              0                       0               1
# 2014-10-02              1                       0               0
# 2014-10-02              0                       0               0
# 2014-10-02              0                       0               0
# 2014-10-02              0                       0               0
# 2014-10-02              0                       0               0
# 2014-10-02              0                       0               0
# 2014-10-02              0                       1               0
# 2014-10-02              0                       0               1
# 2014-10-02              1                       0               0
# 2014-10-02              0                       0               0
# 2014-10-02              0                       0               0
# 2014-10-02              0                       0               0
# 2014-10-02              0                       0               0
# 2014-10-02              0                       0               0
#
#             CULEX SALINARIUS  CULEX TARSALIS  CULEX TERRITANS
# Date
# 2008-06-11                 0               0                0
# 2008-06-11                 0               0                0
# 2008-06-11                 0               0                0
# 2008-06-11                 1               0                0
# 2008-06-11                 0               0                1
# 2008-06-11                 0               1                0
# 2008-06-11                 0               0                0
# 2008-06-11                 0               0                0
# 2008-06-11                 0               0                0
# 2008-06-11                 0               0                0
# 2008-06-11                 0               0                0
# 2008-06-11                 1               0                0
# 2008-06-11                 0               0                1
# 2008-06-11                 0               1                0
# 2008-06-11                 0               0                0
# 2008-06-11                 0               0                0
# 2008-06-11                 0               0                0
# 2008-06-11                 0               0                0
# 2008-06-11                 0               0                0
# 2008-06-11                 1               0                0
# 2008-06-11                 0               0                1
# 2008-06-11                 0               1                0
# 2008-06-11                 0               0                0
# 2008-06-11                 0               0                0
# 2008-06-11                 0               0                0
# 2008-06-11                 0               0                0
# 2008-06-11                 0               0                0
# 2008-06-11                 1               0                0
# 2008-06-11                 0               0                1
# 2008-06-11                 0               1                0
# ...                      ...             ...              ...
# 2014-10-02                 0               0                0
# 2014-10-02                 1               0                0
# 2014-10-02                 0               0                1
# 2014-10-02                 0               1                0
# 2014-10-02                 0               0                0
# 2014-10-02                 0               0                0
# 2014-10-02                 0               0                0
# 2014-10-02                 0               0                0
# 2014-10-02                 0               0                0
# 2014-10-02                 1               0                0
# 2014-10-02                 0               0                1
# 2014-10-02                 0               1                0
# 2014-10-02                 0               0                0
# 2014-10-02                 0               0                0
# 2014-10-02                 0               0                0
# 2014-10-02                 0               0                0
# 2014-10-02                 0               0                0
# 2014-10-02                 1               0                0
# 2014-10-02                 0               0                1
# 2014-10-02                 0               1                0
# 2014-10-02                 0               0                0
# 2014-10-02                 0               0                0
# 2014-10-02                 0               0                0
# 2014-10-02                 0               0                0
# 2014-10-02                 0               0                0
# 2014-10-02                 1               0                0
# 2014-10-02                 0               0                1
# 2014-10-02                 0               1                0
# 2014-10-02                 0               0                0
# 2014-10-02                 0               0                0
#
# [116293 rows x 26 columns]

# %% [markdown]
# ### 4.1.3 Weather

# %%
df_test = df_test.join(df_rolling, how='left')

# %% [markdown]
# ### 4.1.4 Drops

# %%
df_test = df_test.drop(cols_to_drop, axis=1)

# %%
df_test.shape
# Out:
# (116293, 49)

# %% [markdown]
# ## 4.2 Predict

# %%
df_test_X = df_test.loc[:, model_cols]

# %%
[col for col in df_test_X.columns if col not in X.columns]
# Out:
# []

# %%
df_test_preds = knc.predict(df_test_X)

# %%
df_test_probas = knc.predict_proba(df_test_X)

# %%
df_test_preds_adj = [1*(proba[1]>.15) for proba in df_test_probas]

# %% [markdown]
# ## 4.3 Asses

# %%
df_test_preds.sum()
# Out:
# 135

# %%
sum(df_test_preds_adj)/len(df_test_preds_adj)
# Out:
# 0.07375336434695123

# %%
df_test_proba_1 = [df_test_probas[i][1] for i in range(len(df_test_probas))]

# %%
sns.distplot(df_test_proba_1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# # 5 Output Results

# %%
df_outputs = pd.DataFrame(df_test.Id)

# %%
df_outputs['WnvPresent'] = df_test_preds_adj

# %%
df_outputs = df_outputs.reset_index().drop('Date', axis=1)

# %%
now_month = datetime.datetime.now().month
now_day = datetime.datetime.now().day
now_hour = datetime.datetime.now().hour
now_minute = datetime.datetime.now().minute

# %%
output_title = './Predictions/Predictions_{}.{}_{}{}.csv'.format(now_month, now_day, now_hour, now_minute)

# %%
df_outputs.to_csv(output_title, index=False)
